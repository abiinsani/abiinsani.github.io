# %% [markdown]
# # Project 2

# %% [markdown]
# ## Do Countries that Spend More on Education Use More Electricity per Capita?

# %% [markdown]
# By Abi Insani

# %% [markdown]
# ### Introduction

# %% [markdown]
# **Dataset:**
#
# I am using two World Bank datasets:
# - **Electricity Consumption per capita** (kWh per person)
# - **Government Expenditure on Education** (% of GDP)
#
# Also focued on **G20 Countries**, which gives a mix of advanced and emerging economies.

# %% [markdown]
# **Research Question**
#
# *Among G20 countries, is higher government spending on education (as a share of GDP) associated with higher electricity consumption per capita?*

# %% [markdown]
# **Hypothesis**
#
# G20 countries with higher education spending (% of GDP) tend to have **higher electricity consumption per capita**, because more investment in education is associated with higher income, more industrial activity, and greater access to electricity.
#
# *Note: The project does **not** try to prove causality — just to check if there is a visible relationship in the data.*

# %% [markdown]
# ### I. Data Sources and Preparation

# %% [markdown]
# For this project, I use two World Bank indicators to explore whether higher education spending (% of GDP) is associated with higher electricity consumption per capita (kWh) across G20 countries. The datasets come in the standard World Bank Excel format, which requires light preprocessing (e.g., skipping metadata rows, selecting country-year values). I focus only on G20 members and select panel data year from 2010-2020 based on the most complete overlapping data across both indicators. All cleaning and merging steps are done in Python with pandas.
#
# *Datasets Used:*
#
# **1. Electric power consumption (kWh per capita)** as **ELEC_CONS**
#
# **2. Government expenditure on education, total (% of GDP)** as **EXP_EDU**
#
#
# **Preparation Steps**
#
# 1. Load both Excel files (since World Bank datasets have markdown first 3 rows, we skip reading it).
#
# 2. Filter the data to G20 country codes only.
#
# 3. Convert both datasets into panel (long) format by vertical stacking and only show relevant columns.
#
# 4. Merge and clean the datasets using country codes.

# %% [markdown]
# Lets begin! First I need to import the necessary packages - pandas and plotly to analyze the data and display charts and other visualization tools

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected+plotly_mimetype"

# %% [markdown]
# ### Step 1: Load both Excel files

# %% [markdown]
# Now we read the Electric power consumption (kWh per capita) as **elec_cons**:

# %%
elec_cons = pd.read_excel("ELEC_CONS_PER_CAPITA.xls", skiprows=3)
elec_cons.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                 Indicator Name     Indicator Code  1960  1961  \
# 0  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
# 1  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
# 2  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
# 3  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
# 4  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
#
#    1962  1963  1964  1965  ...        2015        2016        2017  \
# 0   NaN   NaN   NaN   NaN  ...         NaN         NaN         NaN
# 1   NaN   NaN   NaN   NaN  ...  582.708405  568.703452  566.073368
# 2   NaN   NaN   NaN   NaN  ...         NaN         NaN         NaN
# 3   NaN   NaN   NaN   NaN  ...  201.734660  215.380351  179.972422
# 4   NaN   NaN   NaN   NaN  ...  306.167407  331.664900  315.199297
#
#          2018        2019        2020        2021        2022  2023  2024
# 0         NaN         NaN         NaN         NaN         NaN   NaN   NaN
# 1  568.141299  548.496602  512.766661  514.341833  501.466616   NaN   NaN
# 2         NaN         NaN         NaN         NaN         NaN   NaN   NaN
# 3  182.920554  188.361690  193.378593  200.861531  203.999368   NaN   NaN
# 4  370.736573  410.864566  437.653351  392.355835  392.507047   NaN   NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# Now we read overnment expenditure on education, total (% of GDP)** as **exp_edu**:

# %%
exp_edu = pd.read_excel("GOV_EXP_ED_PERC_GDP.xls", skiprows=3)
exp_edu.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...      2015      2016      2017      2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  5.888270  5.491360  4.455820  4.548764
# 1   NaN   NaN   NaN   NaN   NaN  ...  4.737919  4.692000  4.430510  4.739750
# 2   NaN   NaN   NaN   NaN   NaN  ...  3.255800  4.543970  4.343190       NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...  3.138830  2.615035  3.296630  3.051252
# 4   NaN   NaN   NaN   NaN   NaN  ...  3.486896  2.754937  2.466879  2.183513
#
#        2019      2020      2021      2022      2023  2024
# 0  4.435037       NaN  3.618558       NaN       NaN   NaN
# 1  4.511410  4.090565  4.368379  3.697668  3.962293   NaN
# 2       NaN       NaN       NaN       NaN       NaN   NaN
# 3  3.047399  3.398741  3.096926  2.891687  3.215620   NaN
# 4  2.073064  2.667447  2.297197  2.385359  2.512737   NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Step 2: Filter the data to G20 country codes only

# %% [markdown]
# The next step is we want to filter both datasets on G20 countries, which includes:
# - Argentina
# - Australia
# - Brazil
# - Canada
# - China
# - France
# - Germany
# - India
# - Indonesia
# - Italy
# - Japan
# - Mexico
# - Russia
# - Saudi Arabia
# - South Africa
# - South Korea
# - Turkey
# - European Union (as a group)
#
# We display the filtered **elec_cons** dataset first:

# %%
# Define G20 Countries list
g20_list = [
    "Argentina",
    "Australia",
    "Brazil",
    "Canada",
    "China",
    "France",
    "Germany",
    "India",
    "Indonesia",
    "Italy",
    "Japan",
    "Mexico",
    "Russian Federation",
    "Saudi Arabia",
    "South Africa",
    "Korea, Rep.",
    "Turkiye",
    "United Kingdom",
    "United States",
    "European Union",
]

# Filter only G20 Countries
elec_cons = elec_cons[elec_cons["Country Name"].isin(g20_list)]
exp_edu = exp_edu[exp_edu["Country Name"].isin(g20_list)]

elec_cons.head()
exp_edu.head()
# Out:
#    Country Name Country Code  \
# 9     Argentina          ARG
# 13    Australia          AUS
# 29       Brazil          BRA
# 35       Canada          CAN
# 40        China          CHN
#
#                                        Indicator Name     Indicator Code  \
# 9   Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# 13  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# 29  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# 35  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# 40  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
#
#     1960  1961  1962  1963  1964  1965  ...     2015     2016     2017  \
# 9    NaN   NaN   NaN   NaN   NaN   NaN  ...  5.77611  5.54549  5.45432
# 13   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN
# 29   NaN   NaN   NaN   NaN   NaN   NaN  ...  6.24106  6.31404  6.32048
# 35   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.73938  4.81642  4.95997
# 40   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN
#
#        2018     2019     2020     2021     2022     2023  2024
# 9   4.87774  4.77165  5.27690  4.65393  4.79263  5.89754   NaN
# 13      NaN      NaN  5.38625  5.34109  5.05916      NaN   NaN
# 29  6.08851  5.96347  5.77150  5.49698  5.61923      NaN   NaN
# 35  4.88898  4.77293  4.88795  4.74860  4.88022      NaN   NaN
# 40      NaN      NaN      NaN      NaN      NaN  4.00128   NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Step 3: Convert both datasets into long format and only show relevant columns

# %% [markdown]
# In this step, we want to produce **One row** per **One year** of country data by using **Melt** function:

# %%
# Melt elec_cons
elec_cons_long = elec_cons.melt(
    id_vars=["Country Name", "Country Code"],
    var_name="Year",
    value_name="Electricity per Capita (kWh)",
)
# Melt exp_edu
exp_edu_long = exp_edu.melt(
    id_vars=["Country Name", "Country Code"],
    var_name="Year",
    value_name="Education Spending as Percentage of GDP (% GDP)",
)

# %% [markdown]
# After this, we clean "Year" Column so it only shows integer and keep year 2010-2020 as the scope of our analysis:

# %%
# Convert Year to numeric
elec_cons_long["Year"] = pd.to_numeric(elec_cons_long["Year"], errors="coerce")
exp_edu_long["Year"] = pd.to_numeric(exp_edu_long["Year"], errors="coerce")

# Drop rows where Year is NaN
elec_cons_long = elec_cons_long.dropna(subset=["Year"])
exp_edu_long = exp_edu_long.dropna(subset=["Year"])

# Convert to integer safely
elec_cons_long["Year"] = elec_cons_long["Year"].astype("int64")
exp_edu_long["Year"] = exp_edu_long["Year"].astype("int64")

# Only include year 2010 and 2020
elec_cons_long = elec_cons_long[
    (elec_cons_long["Year"] >= 2010) & (elec_cons_long["Year"] <= 2020)
]
exp_edu_long = exp_edu_long[
    (exp_edu_long["Year"] >= 2010) & (exp_edu_long["Year"] <= 2020)
]

# %% [markdown]
# ### Step 4: Merge and clean the datasets

# %% [markdown]
# Now finally we can merge two datasets into one big dataset called **df_panel**:

# %%
# Merge the datasets
df_panel = pd.merge(
    elec_cons_long,
    exp_edu_long,
    on=["Country Name", "Country Code", "Year"],
    how="inner",
)
df_panel
# Out:
#            Country Name Country Code  Year Electricity per Capita (kWh)  \
# 0             Argentina          ARG  2010                  2777.733779
# 1             Australia          AUS  2010                 10797.871254
# 2                Brazil          BRA  2010                  2398.608018
# 3                Canada          CAN  2010                 16236.475656
# 4                 China          CHN  2010                  2943.589954
# ..                  ...          ...   ...                          ...
# 215  Russian Federation          RUS  2020                  6770.332872
# 216        Saudi Arabia          SAU  2020                  11356.68763
# 217             Turkiye          TUR  2020                  3318.847059
# 218       United States          USA  2020                 12393.438256
# 219        South Africa          ZAF  2020                  3477.819011
#
#     Education Spending as Percentage of GDP (% GDP)
# 0                                           5.01971
# 1                                               NaN
# 2                                            5.6488
# 3                                           5.35637
# 4                                               NaN
# ..                                              ...
# 215                                        4.016419
# 216                                             NaN
# 217                                         4.03382
# 218                                         5.39532
# 219                                         6.17067
#
# [220 rows x 5 columns]

# %% [markdown]
# Next, we drop NaN values ready for data visualizations:

# %%
# Drop NaN values
df_panel = df_panel.dropna(
    subset=[
        "Electricity per Capita (kWh)",
        "Education Spending as Percentage of GDP (% GDP)",
    ]
)

df_panel
# Out:
#            Country Name Country Code  Year Electricity per Capita (kWh)  \
# 0             Argentina          ARG  2010                  2777.733779
# 2                Brazil          BRA  2010                  2398.608018
# 3                Canada          CAN  2010                 16236.475656
# 5               Germany          DEU  2010                   7265.99788
# 6        European Union          EUU  2010                  6341.755565
# ..                  ...          ...   ...                          ...
# 214              Mexico          MEX  2020                  2354.268353
# 215  Russian Federation          RUS  2020                  6770.332872
# 217             Turkiye          TUR  2020                  3318.847059
# 218       United States          USA  2020                 12393.438256
# 219        South Africa          ZAF  2020                  3477.819011
#
#     Education Spending as Percentage of GDP (% GDP)
# 0                                           5.01971
# 2                                            5.6488
# 3                                           5.35637
# 5                                           4.99525
# 6                                            5.3688
# ..                                              ...
# 214                                         4.49967
# 215                                        4.016419
# 217                                         4.03382
# 218                                         5.39532
# 219                                         6.17067
#
# [167 rows x 5 columns]

# %% [markdown]
# ### II. Visualizing Data and Interpertation
#
# By this point we can now generate visualization based on the merged dataset. We want to visualize the data using scatterplot to plot any linear relationship between **an x-value increase in education spending** vs **y-value increase / decrease in electricity consumption per capita**. This visualization is **descriptive**, not **causal**. We are not yet performing a full econometric analysis (e.g., OLS pooled regression, fixed effects, panel regression). The scatterplot simply illustrates the pattern in the data.
#
# Below are the steps needed:
#
# **Steps**
#
# 1. Select the two variables to visualize.
#
# 2. Generate a visualization.
#
# 3. Interpret the result.

# %% [markdown]
# ### Step 1: Select the two variables to visualize

# %% [markdown]
# We choose:
#
# - X-axis → Education spending (% of GDP)
# - Y-axis → Electricity consumption per capita (kWh per person)
#
# These variables represent government investment in human capital versus the level of development/industrialization.

# %% [markdown]
# ### Step 2: Generate a visualization

# %% [markdown]
# We plot the full dataset (all countries) in one scatterplot using Plotly Express.
# Each dot represents one country in one year.
#
# We include a visual trendline to observe whether the relationship is upward, downward, or flat:

# %%
# Generate scatterplot
fig = px.scatter(
    df_panel,
    x="Education Spending as Percentage of GDP (% GDP)",
    y="Electricity per Capita (kWh)",
    color="Country Name",
    trendline="ols",
    opacity=0.71,
    title="Electricity Consumption vs Education Spending (% GDP)",
    labels={
        "education_pct_gdp": "Education Spending (% of GDP)",
        "electricity_per_capita": "Electricity Consumption (kWh per Capita)",
    },
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d11c9493-8cf6-4e1b-8477-22e1f26477a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d11c9493-8cf6-4e1b-8477-22e1f26477a4")) {                    Plotly.newPlot(                        "d11c9493-8cf6-4e1b-8477-22e1f26477a4",                        [{"hovertemplate":"Country Name=Argentina\u003cbr\u003eEducation Spending as Percentage of GDP (% GDP)=%{x}\u003cbr\u003eElectricity per Capita (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#636efa","opacity":0.71,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[5.01971006393433,5.29062986373901,5.34582996368408,5.43661022186279,5.36144018173218,5.77611017227173,5.54548978805542,5.45431995391846,4.87773990631104,4.7716498374939,5.27689981460571],"xaxis":"x","y":[2777.7337786465223,2880.7835773505617,2917.622836126637,2940.9295448090065,3036.2073361212147,3140.464206693873,3104.989251443378,3005.7648312464066,2971.343648383171,2876.7185272471224,2827.4273977686075],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eElectricity per Capita (kWh) = 254.89 * Education Spending as Percentage of GDP (% GDP) + 1605.14\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.444379\u003cbr\u003e\u003cbr\u003eCountry Name=Argentina\u003cbr\u003eEducation Spending as Percentage of GDP (% GDP)=%{x}\u003cbr\u003eElectricity per Capita (kWh)=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Argentina","showlegend":false,"x":[4.7716498374939,4.87773990631104,5.01971006393433,5.27689981460571,5.29062986373901,5.34582996368408,5.36144018173218,5.43661022186279,5.45431995391846,5.54548978805542,5.77611017227173],"xaxis":"x","y":{"dtype":"f8","bdata":"QDMmWcMKpkCKWmp92ECmQOIZQR04iaZAZ6kLUVQMp0BVF18jVBOnQKI38\u002fN3L6dAoMy3JG03p0CUe70bv12nQG0\u002fCUvGZqdA1e8kSkCVp0BGda8X0QqoQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Brazil\u003cbr\u003eEducation Spending as Percentage of GDP (% GDP)=%{x}\u003cbr\u003eElectricity per Capita (kWh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","marker":{"color":"#EF553B","opacity":0.71,"symbol":"circle"},"mode":"markers","name":"Brazil","orientation":"v","showlegend":true,"x":[5.64879989624023,5.73741006851196,5.85510015487671,5.8388500213623,5.94848012924194,6.24105978012085,6.314040184021,6.32047986984253,6.08851003646851,5.96346998214722,5.77150011062622],"xaxis":"x","y":[2398.608017992428,2458.558793438508,2530.977463284004,2600.6722276474165,2690.214950359604,2628.0976910972026,2592.613373038193,2610.1661356993773,2640.4164383126704,2661.18328561313,2624.8432372375837],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eElectricity per Capita (kWh) = 202.235 * Education Spending as Percentage of GDP (% GDP) + 1376.72\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.291628\u003cbr\u003e\u003cbr\u003eCountry Name=Brazil\u003cbr\u003eEducation Spending as Percentage of GDP (% GDP)=%{x}\u003cbr\u003eElectricity per Capita (kWh)=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Brazil","showlegend":false,"x":[5.64879989624023,5.73741006851196,5.77150011062622,5.8388500213623,5.85510015487671,5.94848012924194,5.96346998214722,6.08851003646851,6.24105978012085,6.314040184021,6.32047986984253] ...

# %% [markdown]
# ### Step 3: Interpret the result

# %% [markdown]
# The data suggest that **there is no strong or consistent relationship between education spending (% of GDP) and electricity consumption per capita** among G20 countries. While a few countries with higher education investment also show higher electricity use, the overall pattern is weak and scattered.
#
# **Key Points**
# - The scatterplot shows **weak correlation**. Countries do not move together in a clear upward or downward trend.
# - Several countries with **similar education spending** have very different electricity consumption levels.
# - The results **do not support the hypothesis** that higher education spending is associated with higher electricity consumption.
#
# Overall, the analysis shows **that higher education spending does not reliably predict electricity consumption per capita** among G20 countries.
#
# *Note: this result is descriptive only, and does not imply causation. A deeper econometric approach would be needed to understand the drivers of electricity use in G20 economies.*
